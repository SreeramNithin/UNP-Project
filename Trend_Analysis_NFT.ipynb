# %% [markdown]
# <a href="https://colab.research.google.com/github/SreeramNithin/UNP-Projects/blob/main/Trend_Analysis_NFT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_excel("C:\\Users\\Nithin\\OneDrive\\Desktop\\abc.xlsx")
data
# Out:
#     Open  High   Low  Close  Open1  High1  Low1  Close1
# 0   1579  1613  1507   1507     55     54    56      56
# 1   1573  1607  1568   1568     54     54    55      55
# 2   1590  1630  1556   1556     56     55    57      57
# 3   1555  1652  1550   1550     58     57    58      60
# 4   1514  1569  1494   1494     58     57    59      60
# ..   ...   ...   ...    ...    ...    ...   ...     ...
# 95  1243  1272  1199   1199     71     69    70      70
# 96  1143  1239  1135   1135     71     70    71      74
# 97  1051  1146  1050   1050     69     69    69      75
# 98  1125  1126  1050   1050     73     73    71      71
# 99  1128  1185  1113   1113     78     74    72      72
#
# [100 rows x 8 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
sns.pairplot(data.sample(20),x_vars=['Open','High','Low'],y_vars='Close',size=7 , aspect=0.7 , kind = 'reg')
# Out:
# C:\Users\Nithin\anaconda3\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(data.sample(20),x_vars=['Open1','High1','Low1'],y_vars='Close1',size=7 , aspect=0.7 , kind = 'reg')
# Out:
# C:\Users\Nithin\anaconda3\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
from sklearn.model_selection import train_test_split
import sklearn
import sklearn.metrics as met

x = data.drop(['Open','High','Low','Close','Close1'],axis=1)
y = data.Close1
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.30,random_state=42)
lm1 = LinearRegression()
lm1.fit(x_train,y_train)
y_pred = lm1.predict(x_test)
print(y_pred)
print(np.sqrt(met.mean_squared_error(y_test,y_pred)))
# Out:
# [82.28723608 72.64507374 78.65542533 61.45601881 59.67063521 64.84933855
#  64.06998067 91.91189207 60.17364807 55.77123262 64.23867495 60.00495378
#  85.50310836 58.77794341 73.81104057 59.11226198 88.45752878 91.96418244
#  58.83898696 60.22593844 74.48274771 75.98610311 55.88763653 63.00859458
#  76.10250702 62.40100098 64.74168781 72.64507374 60.94993595 79.60040751]
# 1.6961187540180227

# %%
plt.figure(figsize=(10,10))
p = sns.boxplot(data = data,orient = 'v',width=0.8)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'Open'),
#   Text(1, 0, 'High'),
#   Text(2, 0, 'Low'),
#   Text(3, 0, 'Close'),
#   Text(4, 0, 'Open1'),
#   Text(5, 0, 'High1'),
#   Text(6, 0, 'Low1'),
#   Text(7, 0, 'Close1')])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    100 non-null    float64
#  1   High    100 non-null    float64
#  2   Low     100 non-null    float64
#  3   Close   100 non-null    float64
#  4           0 non-null      float64
#  5   Open1   100 non-null    float64
#  6   High1   100 non-null    float64
#  7   Low1    100 non-null    float64
#  8   Close1  100 non-null    float64
# dtypes: float64(9)
# memory usage: 7.2 KB
